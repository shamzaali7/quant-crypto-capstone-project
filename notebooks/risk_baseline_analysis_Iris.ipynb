# %% [markdown]
# <a href="https://colab.research.google.com/github/shamzaali7/quant-crypto-capstone-project/blob/main/notebooks/risk_baseline_analysis_Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Risk_basedline_Analysis_iris
