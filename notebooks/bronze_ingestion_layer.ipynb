# %% [markdown]
# <a href="https://colab.research.google.com/github/shamzaali7/quant-crypto-capstone-project/blob/main/notebooks/bronze_ingestion_layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

data_path = "/content/drive/MyDrive/Capstone_Crypto/Data/chapter1_master_matrix_FULL_v3.csv"

df = pd.read_csv(data_path)
df.head(20)
# Out:
#           Date  Intl_Shanghai  Eq_BlackRock  BTC_Spot_Price  Eq_Coinbase  \
# 0   2020-01-08    3066.893066    507.100006     8079.862793          NaN
# 1   2020-01-09    3094.882080    513.099976     7879.071289          NaN
# 2   2020-01-10    3092.291016    512.179993     8166.554199          NaN
# 3   2020-01-11    3092.291016    512.179993     8037.537598          NaN
# 4   2020-01-12    3092.291016    512.179993     8192.494141          NaN
# 5   2020-01-13    3115.570068    523.109985     8144.194336          NaN
# 6   2020-01-14    3106.820068    518.320007     8827.764648          NaN
# 7   2020-01-15    3090.040039    530.260010     8807.010742          NaN
# 8   2020-01-16    3074.081055    535.000000     8723.786133          NaN
# 9   2020-01-17    3075.496094    535.239990     8929.038086          NaN
# 10  2020-01-18    3075.496094    535.239990     8942.808594          NaN
# 11  2020-01-19    3075.496094    535.239990     8706.245117          NaN
# ...

# %%
print("(Num Rows, Num Columns)")
df.shape
# Out:
# (Num Rows, Num Columns)
# (2194, 66)

# %%
df.columns
# Out:
# Index(['Date', 'Intl_Shanghai', 'Eq_BlackRock', 'BTC_Spot_Price',
#        'Eq_Coinbase', 'Macro_DXY', 'Eq_Robinhood', 'Eq_JPM',
#        'Eq_MorganStanley', 'Eq_Nvidia', 'Eq_Block', 'US_DowJones',
#        'Intl_FTSE100', 'US_SP500', 'Intl_HangSeng', 'US_Nasdaq',
#        'Intl_Euronext100', 'Intl_Nikkei225', 'US_Russell2000', 'Macro_US10Y',
#        'Macro_VIX', 'Log_Ret', 'Target_RV_7D', 'Target_RV_Proxy',
#        'LogRet_Intl_Shanghai', 'LogRet_Eq_BlackRock', 'LogRet_BTC_Spot_Price',
#        'LogRet_Eq_Coinbase', 'LogRet_Macro_DXY', 'LogRet_Eq_Robinhood',
#        'LogRet_Eq_JPM', 'LogRet_Eq_MorganStanley', 'LogRet_Eq_Nvidia',
#        'LogRet_Eq_Block', 'LogRet_US_DowJones', 'LogRet_Intl_FTSE100',
#        'LogRet_US_SP500', 'LogRet_Intl_HangSeng', 'LogRet_US_Nasdaq',
#        'LogRet_Intl_Euronext100', 'LogRet_Intl_Nikkei225',
#        'LogRet_US_Russell2000', 'LogRet_Macro_US10Y', 'LogRet_Macro_VIX',
#        'OnChain_AdrActCnt', 'OnChain_TxCnt', 'OnChain_FeeTotNtv',
# ...
